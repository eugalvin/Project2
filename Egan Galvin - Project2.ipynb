# %%
# %pip install langchain-ollama
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2:latest", temperature=0)

# %%
msg = llm.invoke("What is operations management?")

# %%
print(msg.content)
# Out:
# Operations Management (OM) is a branch of management that focuses on the planning, organization, and supervision of production processes within an organization. It involves the coordination and control of resources to produce goods or services in a way that meets customer needs while minimizing costs.
#
# The primary goal of Operations Management is to maximize efficiency, productivity, and quality by optimizing the use of resources such as labor, materials, equipment, and technology. This is achieved through the application of various techniques and tools, including:
#
# 1. Production planning: Determining the quantities and timing of production to meet customer demand.
# 2. Supply chain management: Managing the flow of goods, services, and information from raw materials to end customers.
# 3. Inventory management: Controlling the levels of inventory to minimize waste and maximize efficiency.
# ...
